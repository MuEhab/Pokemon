# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('pokemon.csv')
df
# Out:
#        #        Name   Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 0      1   Bulbasaur    Grass  Poison    318   45      49       49       65
# 1      2     Ivysaur    Grass  Poison    405   60      62       63       80
# 2      3    Venusaur    Grass  Poison    525   80      82       83      100
# 3      4  Charmander     Fire     NaN    309   39      52       43       60
# 4      5  Charmeleon     Fire     NaN    405   58      64       58       80
# ..   ...         ...      ...     ...    ...  ...     ...      ...      ...
# 146  147     Dratini   Dragon     NaN    300   41      64       45       50
# 147  148   Dragonair   Dragon     NaN    420   61      84       65       70
# 148  149   Dragonite   Dragon  Flying    600   91     134       95      100
# 149  150      Mewtwo  Psychic     NaN    680  106     110       90      154
# 150  151         Mew  Psychic     NaN    600  100     100      100      100
#
#      Sp. Def  Speed  Legendary
# ...

# %%
df.duplicated().value_counts()
# Out:
# False    151
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 151 entries, 0 to 150
# Data columns (total 12 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   #          151 non-null    int64
#  1   Name       151 non-null    object
#  2   Type 1     151 non-null    object
#  3   Type 2     67 non-null     object
#  4   Total      151 non-null    int64
#  5   HP         151 non-null    int64
#  6   Attack     151 non-null    int64
#  7   Defense    151 non-null    int64
#  8   Sp. Atk    151 non-null    int64
#  9   Sp. Def    151 non-null    int64
#  10  Speed      151 non-null    int64
#  11  Legendary  151 non-null    bool
# dtypes: bool(1), int64(8), object(3)
# memory usage: 13.2+ KB

# %%
df.describe()
# Out:
#                 #      Total          HP      Attack     Defense     Sp. Atk  \
# count  151.000000  151.00000  151.000000  151.000000  151.000000  151.000000
# mean    76.000000  407.07947   64.211921   72.549669   68.225166   67.139073
# std     43.734045   99.74384   28.590117   26.596162   26.916704   28.534199
# min      1.000000  195.00000   10.000000    5.000000    5.000000   15.000000
# 25%     38.500000  320.00000   45.000000   51.000000   50.000000   45.000000
# 50%     76.000000  405.00000   60.000000   70.000000   65.000000   65.000000
# 75%    113.500000  490.00000   80.000000   90.000000   84.000000   87.500000
# max    151.000000  680.00000  250.000000  134.000000  180.000000  154.000000
#
#           Sp. Def       Speed
# count  151.000000  151.000000
# mean    66.019868   68.933775
# std     24.197926   26.746880
# min     20.000000   15.000000
# 25%     49.000000   46.500000
# 50%     65.000000   70.000000
# 75%     80.000000   90.000000
# ...

# %%
df.describe(include = 'O')
# Out:
#             Name Type 1  Type 2
# count        151    151      67
# unique       151     15      11
# top     Kabutops  Water  Flying
# freq           1     28      19

# %%
df.nunique()
# Out:
# #            151
# Name         151
# Type 1        15
# Type 2        11
# Total         74
# HP            42
# Attack        46
# Defense       44
# Sp. Atk       34
# Sp. Def       29
# Speed         42
# Legendary      2
# dtype: int64

# %%
legendary_counts = df["Legendary"].value_counts()
labels = legendary_counts.index
values = legendary_counts.values 
plt.figure(figsize=(6, 6))
plt.pie(values, labels=labels, autopct='%1.1f%%', startangle=140)
plt.title("Distribution of Legendary Pokémon")
plt.axis('equal')
plt.show()

# %%
condition = df['Legendary'] == True
df = df[~condition]
df = df.reset_index(drop=True)
df
# Out:
#        #        Name   Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 0      1   Bulbasaur    Grass  Poison    318   45      49       49       65
# 1      2     Ivysaur    Grass  Poison    405   60      62       63       80
# 2      3    Venusaur    Grass  Poison    525   80      82       83      100
# 3      4  Charmander     Fire     NaN    309   39      52       43       60
# 4      5  Charmeleon     Fire     NaN    405   58      64       58       80
# ..   ...         ...      ...     ...    ...  ...     ...      ...      ...
# 142  143     Snorlax   Normal     NaN    540  160     110       65       65
# 143  147     Dratini   Dragon     NaN    300   41      64       45       50
# 144  148   Dragonair   Dragon     NaN    420   61      84       65       70
# 145  149   Dragonite   Dragon  Flying    600   91     134       95      100
# 146  151         Mew  Psychic     NaN    600  100     100      100      100
#
#      Sp. Def  Speed  Legendary
# ...

# %%
df = df.drop("Legendary", axis=1)
df
# Out:
#        #        Name   Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 0      1   Bulbasaur    Grass  Poison    318   45      49       49       65
# 1      2     Ivysaur    Grass  Poison    405   60      62       63       80
# 2      3    Venusaur    Grass  Poison    525   80      82       83      100
# 3      4  Charmander     Fire     NaN    309   39      52       43       60
# 4      5  Charmeleon     Fire     NaN    405   58      64       58       80
# ..   ...         ...      ...     ...    ...  ...     ...      ...      ...
# 142  143     Snorlax   Normal     NaN    540  160     110       65       65
# 143  147     Dratini   Dragon     NaN    300   41      64       45       50
# 144  148   Dragonair   Dragon     NaN    420   61      84       65       70
# 145  149   Dragonite   Dragon  Flying    600   91     134       95      100
# 146  151         Mew  Psychic     NaN    600  100     100      100      100
#
#      Sp. Def  Speed
# 0         65     45
# ...

# %%
condition = df['Name'] == "Mew"
df = df[~condition]
df = df.reset_index(drop=True)
df
# Out:
#        #        Name  Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 0      1   Bulbasaur   Grass  Poison    318   45      49       49       65
# 1      2     Ivysaur   Grass  Poison    405   60      62       63       80
# 2      3    Venusaur   Grass  Poison    525   80      82       83      100
# 3      4  Charmander    Fire     NaN    309   39      52       43       60
# 4      5  Charmeleon    Fire     NaN    405   58      64       58       80
# ..   ...         ...     ...     ...    ...  ...     ...      ...      ...
# 141  142  Aerodactyl    Rock  Flying    515   80     105       65       60
# 142  143     Snorlax  Normal     NaN    540  160     110       65       65
# 143  147     Dratini  Dragon     NaN    300   41      64       45       50
# 144  148   Dragonair  Dragon     NaN    420   61      84       65       70
# 145  149   Dragonite  Dragon  Flying    600   91     134       95      100
#
#      Sp. Def  Speed
# 0         65     45
# 1         80     60
# ...

# %%
pokemon_less_than_500 = df[df["Total"] < 500]
pokemon_greater_than_500 = df[df["Total"] >= 500]
count_less_than_500 = len(pokemon_less_than_500)
count_greater_than_500 = len(pokemon_greater_than_500)
pokemon_counts = [count_less_than_500, count_greater_than_500]
labels = ["Total < 500", "Total >= 500"]
plt.figure(figsize=(6, 6))
plt.pie(pokemon_counts, labels=labels, autopct='%1.1f%%', startangle=140)
plt.title("Distribution of Pokémon by Total Score")
plt.axis('equal') 
plt.show()

# %%
condition = df['Total'] < 500
df = df[~condition]
df = df.reset_index(drop=True)
df
# Out:
#       #        Name    Type 1    Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 0     3    Venusaur     Grass    Poison    525   80      82       83      100
# 1     6   Charizard      Fire    Flying    534   78      84       78      109
# 2     9   Blastoise     Water       NaN    530   79      83      100       85
# 3    31   Nidoqueen    Poison    Ground    505   90      92       87       75
# 4    34    Nidoking    Poison    Ground    505   81     102       77       85
# 5    38   Ninetales      Fire       NaN    505   73      76       75       81
# 6    55     Golduck     Water       NaN    500   80      82       78       95
# 7    59    Arcanine      Fire       NaN    555   90     110       80      100
# 8    62   Poliwrath     Water  Fighting    510   90      95       95       70
# 9    65    Alakazam   Psychic       NaN    500   55      50       45      135
# 10   68     Machamp  Fighting       NaN    505   90     130       80       65
# ...

# %%
df.sort_values(by='Total',ascending = False)
# Out:
#       #        Name    Type 1    Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 27  149   Dragonite    Dragon    Flying    600   91     134       95      100
# 7    59    Arcanine      Fire       NaN    555   90     110       80      100
# 26  143     Snorlax    Normal       NaN    540  160     110       65       65
# 20  130    Gyarados     Water    Flying    540   95     125       79       60
# 21  131      Lapras     Water       Ice    535  130      85       80       85
# 1     6   Charizard      Fire    Flying    534   78      84       78      109
# 2     9   Blastoise     Water       NaN    530   79      83      100       85
# 24  136     Flareon      Fire       NaN    525   65     130       60       95
# 23  135     Jolteon  Electric       NaN    525   65      65       60      110
# 22  134    Vaporeon     Water       NaN    525  130      65       60      110
# 0     3    Venusaur     Grass    Poison    525   80      82       83      100
# ...

# %%
df[df['Total'] >= 540]
# Out:
#       #       Name  Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 7    59   Arcanine    Fire     NaN    555   90     110       80      100
# 20  130   Gyarados   Water  Flying    540   95     125       79       60
# 26  143    Snorlax  Normal     NaN    540  160     110       65       65
# 27  149  Dragonite  Dragon  Flying    600   91     134       95      100
#
#     Sp. Def  Speed
# 7        80     95
# 20      100     81
# 26      110     30
# 27      100     80

# %%
my_team = []
for Name, Total in df.iterrows():
    if Total['Total'] >= 540:
        my_team.append(Total['Name'])
my_team
# Out:
# ['Arcanine', 'Gyarados', 'Snorlax', 'Dragonite']

# %%
df[df['Total'] >= 540]
# Out:
#       #       Name  Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 7    59   Arcanine    Fire     NaN    555   90     110       80      100
# 20  130   Gyarados   Water  Flying    540   95     125       79       60
# 26  143    Snorlax  Normal     NaN    540  160     110       65       65
# 27  149  Dragonite  Dragon  Flying    600   91     134       95      100
#
#     Sp. Def  Speed
# 7        80     95
# 20      100     81
# 26      110     30
# 27      100     80

# %%
condition = df['Type 1'] == "Fire"
df = df[~condition]
df = df.reset_index(drop=True)
df
# Out:
#       #        Name    Type 1    Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 0     3    Venusaur     Grass    Poison    525   80      82       83      100
# 1     9   Blastoise     Water       NaN    530   79      83      100       85
# 2    31   Nidoqueen    Poison    Ground    505   90      92       87       75
# 3    34    Nidoking    Poison    Ground    505   81     102       77       85
# 4    55     Golduck     Water       NaN    500   80      82       78       95
# 5    62   Poliwrath     Water  Fighting    510   90      95       95       70
# 6    65    Alakazam   Psychic       NaN    500   55      50       45      135
# 7    68     Machamp  Fighting       NaN    505   90     130       80       65
# 8    73  Tentacruel     Water    Poison    515   80      70       65       80
# 9    89         Muk    Poison       NaN    500  105     105       75       65
# 10   91    Cloyster     Water       Ice    525   50      95      180       85
# ...

# %%
condition = df['Type 2'] == "Fire"
df = df[~condition]
df = df.reset_index(drop=True)
df
# Out:
#       #        Name    Type 1    Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 0     3    Venusaur     Grass    Poison    525   80      82       83      100
# 1     9   Blastoise     Water       NaN    530   79      83      100       85
# 2    31   Nidoqueen    Poison    Ground    505   90      92       87       75
# 3    34    Nidoking    Poison    Ground    505   81     102       77       85
# 4    55     Golduck     Water       NaN    500   80      82       78       95
# 5    62   Poliwrath     Water  Fighting    510   90      95       95       70
# 6    65    Alakazam   Psychic       NaN    500   55      50       45      135
# 7    68     Machamp  Fighting       NaN    505   90     130       80       65
# 8    73  Tentacruel     Water    Poison    515   80      70       65       80
# 9    89         Muk    Poison       NaN    500  105     105       75       65
# 10   91    Cloyster     Water       Ice    525   50      95      180       85
# ...

# %%
df[df['Total'] >= 540]
# Out:
#       #       Name  Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 16  130   Gyarados   Water  Flying    540   95     125       79       60
# 21  143    Snorlax  Normal     NaN    540  160     110       65       65
# 22  149  Dragonite  Dragon  Flying    600   91     134       95      100
#
#     Sp. Def  Speed
# 16      100     81
# 21      110     30
# 22      100     80

# %%
condition = df['Type 1'] == "Water"
df = df[~condition]
df = df.reset_index(drop=True)
df
# Out:
#       #        Name    Type 1   Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 0     3    Venusaur     Grass   Poison    525   80      82       83      100
# 1    31   Nidoqueen    Poison   Ground    505   90      92       87       75
# 2    34    Nidoking    Poison   Ground    505   81     102       77       85
# 3    65    Alakazam   Psychic      NaN    500   55      50       45      135
# 4    68     Machamp  Fighting      NaN    505   90     130       80       65
# 5    89         Muk    Poison      NaN    500  105     105       75       65
# 6    94      Gengar     Ghost   Poison    500   60      65       60      130
# 7   103   Exeggutor     Grass  Psychic    520   95      95       85      125
# 8   123     Scyther       Bug   Flying    500   70     110       80       55
# 9   127      Pinsir       Bug      NaN    500   65     125      100       55
# 10  135     Jolteon  Electric      NaN    525   65      65       60      110
# ...

# %%
condition = df['Type 2'] == "Water"
df = df[~condition]
df = df.reset_index(drop=True)
df
# Out:
#       #        Name    Type 1   Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 0     3    Venusaur     Grass   Poison    525   80      82       83      100
# 1    31   Nidoqueen    Poison   Ground    505   90      92       87       75
# 2    34    Nidoking    Poison   Ground    505   81     102       77       85
# 3    65    Alakazam   Psychic      NaN    500   55      50       45      135
# 4    68     Machamp  Fighting      NaN    505   90     130       80       65
# 5    89         Muk    Poison      NaN    500  105     105       75       65
# 6    94      Gengar     Ghost   Poison    500   60      65       60      130
# 7   103   Exeggutor     Grass  Psychic    520   95      95       85      125
# 8   123     Scyther       Bug   Flying    500   70     110       80       55
# 9   127      Pinsir       Bug      NaN    500   65     125      100       55
# 10  135     Jolteon  Electric      NaN    525   65      65       60      110
# ...

# %%
df[df['Total'] >= 540]
# Out:
#       #       Name  Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 12  143    Snorlax  Normal     NaN    540  160     110       65       65
# 13  149  Dragonite  Dragon  Flying    600   91     134       95      100
#
#     Sp. Def  Speed
# 12      110     30
# 13      100     80

# %%
condition = df['Type 1'] == "Dragon"
df = df[~condition]
df = df.reset_index(drop=True)
df
# Out:
#       #        Name    Type 1   Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 0     3    Venusaur     Grass   Poison    525   80      82       83      100
# 1    31   Nidoqueen    Poison   Ground    505   90      92       87       75
# 2    34    Nidoking    Poison   Ground    505   81     102       77       85
# 3    65    Alakazam   Psychic      NaN    500   55      50       45      135
# 4    68     Machamp  Fighting      NaN    505   90     130       80       65
# 5    89         Muk    Poison      NaN    500  105     105       75       65
# 6    94      Gengar     Ghost   Poison    500   60      65       60      130
# 7   103   Exeggutor     Grass  Psychic    520   95      95       85      125
# 8   123     Scyther       Bug   Flying    500   70     110       80       55
# 9   127      Pinsir       Bug      NaN    500   65     125      100       55
# 10  135     Jolteon  Electric      NaN    525   65      65       60      110
# ...

# %%
condition = df['Type 2'] == "Dragon"
df = df[~condition]
df = df.reset_index(drop=True)
df
# Out:
#       #        Name    Type 1   Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 0     3    Venusaur     Grass   Poison    525   80      82       83      100
# 1    31   Nidoqueen    Poison   Ground    505   90      92       87       75
# 2    34    Nidoking    Poison   Ground    505   81     102       77       85
# 3    65    Alakazam   Psychic      NaN    500   55      50       45      135
# 4    68     Machamp  Fighting      NaN    505   90     130       80       65
# 5    89         Muk    Poison      NaN    500  105     105       75       65
# 6    94      Gengar     Ghost   Poison    500   60      65       60      130
# 7   103   Exeggutor     Grass  Psychic    520   95      95       85      125
# 8   123     Scyther       Bug   Flying    500   70     110       80       55
# 9   127      Pinsir       Bug      NaN    500   65     125      100       55
# 10  135     Jolteon  Electric      NaN    525   65      65       60      110
# ...

# %%
condition = df['Type 1'] == "Flying"
df = df[~condition]
df = df.reset_index(drop=True)
df
# Out:
#       #        Name    Type 1   Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 0     3    Venusaur     Grass   Poison    525   80      82       83      100
# 1    31   Nidoqueen    Poison   Ground    505   90      92       87       75
# 2    34    Nidoking    Poison   Ground    505   81     102       77       85
# 3    65    Alakazam   Psychic      NaN    500   55      50       45      135
# 4    68     Machamp  Fighting      NaN    505   90     130       80       65
# 5    89         Muk    Poison      NaN    500  105     105       75       65
# 6    94      Gengar     Ghost   Poison    500   60      65       60      130
# 7   103   Exeggutor     Grass  Psychic    520   95      95       85      125
# 8   123     Scyther       Bug   Flying    500   70     110       80       55
# 9   127      Pinsir       Bug      NaN    500   65     125      100       55
# 10  135     Jolteon  Electric      NaN    525   65      65       60      110
# ...

# %%
condition = df['Type 2'] == "Flying"
df = df[~condition]
df = df.reset_index(drop=True)
df
# Out:
#       #       Name    Type 1   Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 0     3   Venusaur     Grass   Poison    525   80      82       83      100
# 1    31  Nidoqueen    Poison   Ground    505   90      92       87       75
# 2    34   Nidoking    Poison   Ground    505   81     102       77       85
# 3    65   Alakazam   Psychic      NaN    500   55      50       45      135
# 4    68    Machamp  Fighting      NaN    505   90     130       80       65
# 5    89        Muk    Poison      NaN    500  105     105       75       65
# 6    94     Gengar     Ghost   Poison    500   60      65       60      130
# 7   103  Exeggutor     Grass  Psychic    520   95      95       85      125
# 8   127     Pinsir       Bug      NaN    500   65     125      100       55
# 9   135    Jolteon  Electric      NaN    525   65      65       60      110
# 10  143    Snorlax    Normal      NaN    540  160     110       65       65
#
#     Sp. Def  Speed
# 0       100     80
# ...

# %%
df[df['Total'] >= 540]
# Out:
#       #     Name  Type 1 Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 10  143  Snorlax  Normal    NaN    540  160     110       65       65
#
#     Sp. Def  Speed
# 10      110     30

# %%
condition = df['Type 1'] == "Normal"
df = df[~condition]
df = df.reset_index(drop=True)
df
# Out:
#      #       Name    Type 1   Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 0    3   Venusaur     Grass   Poison    525   80      82       83      100
# 1   31  Nidoqueen    Poison   Ground    505   90      92       87       75
# 2   34   Nidoking    Poison   Ground    505   81     102       77       85
# 3   65   Alakazam   Psychic      NaN    500   55      50       45      135
# 4   68    Machamp  Fighting      NaN    505   90     130       80       65
# 5   89        Muk    Poison      NaN    500  105     105       75       65
# 6   94     Gengar     Ghost   Poison    500   60      65       60      130
# 7  103  Exeggutor     Grass  Psychic    520   95      95       85      125
# 8  127     Pinsir       Bug      NaN    500   65     125      100       55
# 9  135    Jolteon  Electric      NaN    525   65      65       60      110
#
#    Sp. Def  Speed
# 0      100     80
# 1       85     76
# 2       75     85
# 3       95    120
# 4       85     55
# 5      100     50
# ...

# %%
condition = df['Type 2'] == "Normal"
df = df[~condition]
df = df.reset_index(drop=True)
df
# Out:
#      #       Name    Type 1   Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 0    3   Venusaur     Grass   Poison    525   80      82       83      100
# 1   31  Nidoqueen    Poison   Ground    505   90      92       87       75
# 2   34   Nidoking    Poison   Ground    505   81     102       77       85
# 3   65   Alakazam   Psychic      NaN    500   55      50       45      135
# 4   68    Machamp  Fighting      NaN    505   90     130       80       65
# 5   89        Muk    Poison      NaN    500  105     105       75       65
# 6   94     Gengar     Ghost   Poison    500   60      65       60      130
# 7  103  Exeggutor     Grass  Psychic    520   95      95       85      125
# 8  127     Pinsir       Bug      NaN    500   65     125      100       55
# 9  135    Jolteon  Electric      NaN    525   65      65       60      110
#
#    Sp. Def  Speed
# 0      100     80
# 1       85     76
# 2       75     85
# 3       95    120
# 4       85     55
# 5      100     50
# ...

# %%
my_team
# Out:
# ['Arcanine', 'Gyarados', 'Snorlax', 'Dragonite']

# %%
df.head(1)['Name'][0]
# Out:
# 'Venusaur'

# %%
my_team.append(df.head(1)['Name'][0])
my_team
# Out:
# ['Arcanine', 'Gyarados', 'Snorlax', 'Dragonite', 'Venusaur']

# %%
df.head(1)
# Out:
#    #      Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  3  Venusaur  Grass  Poison    525  80      82       83      100      100
#
#    Speed
# 0     80

# %%
condition = df['Type 1'] == "Grass"
df = df[~condition]
df = df.reset_index(drop=True)
df
# Out:
#      #       Name    Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 0   31  Nidoqueen    Poison  Ground    505   90      92       87       75
# 1   34   Nidoking    Poison  Ground    505   81     102       77       85
# 2   65   Alakazam   Psychic     NaN    500   55      50       45      135
# 3   68    Machamp  Fighting     NaN    505   90     130       80       65
# 4   89        Muk    Poison     NaN    500  105     105       75       65
# 5   94     Gengar     Ghost  Poison    500   60      65       60      130
# 6  127     Pinsir       Bug     NaN    500   65     125      100       55
# 7  135    Jolteon  Electric     NaN    525   65      65       60      110
#
#    Sp. Def  Speed
# 0       85     76
# 1       75     85
# 2       95    120
# 3       85     55
# 4      100     50
# 5       75    110
# 6       70     85
# 7       95    130

# %%
condition = df['Type 2'] == "Grass"
df = df[~condition]
df = df.reset_index(drop=True)
df
# Out:
#      #       Name    Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 0   31  Nidoqueen    Poison  Ground    505   90      92       87       75
# 1   34   Nidoking    Poison  Ground    505   81     102       77       85
# 2   65   Alakazam   Psychic     NaN    500   55      50       45      135
# 3   68    Machamp  Fighting     NaN    505   90     130       80       65
# 4   89        Muk    Poison     NaN    500  105     105       75       65
# 5   94     Gengar     Ghost  Poison    500   60      65       60      130
# 6  127     Pinsir       Bug     NaN    500   65     125      100       55
# 7  135    Jolteon  Electric     NaN    525   65      65       60      110
#
#    Sp. Def  Speed
# 0       85     76
# 1       75     85
# 2       95    120
# 3       85     55
# 4      100     50
# 5       75    110
# 6       70     85
# 7       95    130

# %%
condition = df['Type 1'] == "Poison"
df = df[~condition]
df = df.reset_index(drop=True)
df
# Out:
#      #      Name    Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 0   65  Alakazam   Psychic     NaN    500  55      50       45      135
# 1   68   Machamp  Fighting     NaN    505  90     130       80       65
# 2   94    Gengar     Ghost  Poison    500  60      65       60      130
# 3  127    Pinsir       Bug     NaN    500  65     125      100       55
# 4  135   Jolteon  Electric     NaN    525  65      65       60      110
#
#    Sp. Def  Speed
# 0       95    120
# 1       85     55
# 2       75    110
# 3       70     85
# 4       95    130

# %%
condition = df['Type 2'] == "Poison"
df = df[~condition]
df = df.reset_index(drop=True)
df
# Out:
#      #      Name    Type 1 Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 0   65  Alakazam   Psychic    NaN    500  55      50       45      135
# 1   68   Machamp  Fighting    NaN    505  90     130       80       65
# 2  127    Pinsir       Bug    NaN    500  65     125      100       55
# 3  135   Jolteon  Electric    NaN    525  65      65       60      110
#
#    Sp. Def  Speed
# 0       95    120
# 1       85     55
# 2       70     85
# 3       95    130

# %%
df = df.sort_values(by='Speed',ascending = False)
df
# Out:
#      #      Name    Type 1 Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 3  135   Jolteon  Electric    NaN    525  65      65       60      110
# 0   65  Alakazam   Psychic    NaN    500  55      50       45      135
# 2  127    Pinsir       Bug    NaN    500  65     125      100       55
# 1   68   Machamp  Fighting    NaN    505  90     130       80       65
#
#    Sp. Def  Speed
# 3       95    130
# 0       95    120
# 2       70     85
# 1       85     55

# %%
plt.figure(figsize=(10, 6))
plt.barh(df["Name"], df["Speed"], color="skyblue")
plt.xlabel("Speed")
plt.ylabel("")
plt.title("My fast striker")
plt.gca().invert_yaxis()
plt.tight_layout()

plt.show()

# %%
for Name, Speed in df.iterrows():
    if Speed['Speed'] >= 130:
        my_team.append(Speed['Name'])
my_team
# Out:
# ['Arcanine', 'Gyarados', 'Snorlax', 'Dragonite', 'Venusaur', 'Jolteon']

# %%
df = pd.read_csv('pokemon.csv')
df[df['Name'].isin(my_team)]
# Out:
#        #       Name    Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 2      3   Venusaur     Grass  Poison    525   80      82       83      100
# 58    59   Arcanine      Fire     NaN    555   90     110       80      100
# 129  130   Gyarados     Water  Flying    540   95     125       79       60
# 134  135    Jolteon  Electric     NaN    525   65      65       60      110
# 142  143    Snorlax    Normal     NaN    540  160     110       65       65
# 148  149  Dragonite    Dragon  Flying    600   91     134       95      100
#
#      Sp. Def  Speed  Legendary
# 2        100     80      False
# 58        80     95      False
# 129      100     81      False
# 134       95    130      False
# 142      110     30      False
# 148      100     80      False
